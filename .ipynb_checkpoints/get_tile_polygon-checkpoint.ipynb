# %% [markdown]
# # Préparation du fond de carte

# %%
import os 
import pandas as pd
from shapely.geometry import Point, Polygon
from shapely import wkt
import geopandas

os.chdir('/home/cerezamo/projet_stream/simulator/madrid_sim')

# %%
Antenne_Info=pd.read_csv('AntennaInfo_MNO_MNO1.csv') # Open csv
Antenne_Info.columns=['t','Antenna_Id','Event_code','Device_ID','x','y','Tile_ID'] #Set column names
Antenne_Info=Antenne_Info[['Antenna_Id','x','y']] # Keep interesting stuff
Antenne_Info=Antenne_Info.drop_duplicates(ignore_index=True) # drop duplicates

# %%
# Transform x,y position into shapely like POINTS
geometry = pd.DataFrame([Point(xy) for xy in zip(Antenne_Info.x, Antenne_Info.y)],columns=['geometry'])

# %%
# Merge back with the data 
Antenne_Info=pd.concat([Antenne_Info,geometry],axis=1)

# %%
# Transform panda into geopanda using the geometry defined
gdf = geopandas.GeoDataFrame(Antenne_Info, geometry='geometry')

# %%
# plot 
import matplotlib.image as image
im = image.imread('antenne.png')

# %%
gdf.plot(edgecolor='black',color='black',figsize=(20, 10), marker="^")

# %%
# Antenne_Info.to_csv('Antenne_info_clean.csv',index=False)

# %%
# gdf

# %% [markdown]
# # People

# %%
# ENELVER LES DEUX DERNIERES VARIABLES ! PROBBLEME

# %%
person_Info=pd.read_csv('persons2.csv',sep=';') # Open csv

# %%
person_Info
# Out:
#        t  Person ID              x              y
# 0      0        300  600619.720297  648855.895507
# 1      0        298  600431.357885  648956.498195
# 2      0        295  600995.281445  652785.571876
# 3      0        294  600144.698023  651260.892388
# 4      0        293  599946.186746  650383.760602
# ...   ..        ...            ...            ...
# 2495  49        235  601059.432127  650290.888037
# 2496  49        233  601514.911596  650068.348954
# 2497  49        232  600415.237320  648547.833663
# 2498  49        231  600605.064454  649076.818921
# 2499  49        229  600448.807269  652805.610380
#
# [2500 rows x 4 columns]

# %%
person_Info_0=person_Info[person_Info.t==0]

# %%
person_Info_0=pd.concat([person_Info_0,geometry],axis=1)

# %%
geometry = pd.DataFrame([Point(xy) for xy in zip(person_Info_0.x, person_Info_0.y)],columns=['geometry'])

# %%
sub_gdf = geopandas.GeoDataFrame(person_Info_0, geometry='geometry')

# %%
ax = gdf.plot(edgecolor='black',color='black',figsize=(20, 10), marker="^")
sub_gdf.plot(edgecolor='blue',color='blue',figsize=(20, 10), marker="o",ax=ax)

# %%
import plotly.graph_objects as go

# %%
gdf.columns, sub_gdf.columns
# Out:
# (Index(['Antenna_Id', 'x', 'y', 'geometry', 'text'], dtype='object'),
#  Index(['t', 'Person ID', 'x', 'y', 'geometry'], dtype='object'))

# %%
# Create plotly figure

# gdf is the database with antennes locations
# sub_gdf refers to the BATCH, this the data that should be updated in the app

def create_plot_madrid(gdf,batch,title):
    import plotly.graph_objects as go
    import pandas as pd

    gdf['text'] = gdf['Antenna_Id'].astype(str)
    batch['text'] = batch['Person ID'].astype(str)

    fig = go.Figure()

    fig.add_trace(
       go.Scattergl(
        x = gdf['x'],
        y = gdf['y'],
        text = gdf['text'],
        mode='markers',
        name="Antennes",
        marker_symbol='triangle-up',
        #marker_color = gdf['Antenna_Id']
        marker_color="black",
        marker_size=8
    ))

    fig.add_trace(
        go.Scattergl(
            x=batch["x"],
            y=batch["y"],
            text = batch['text'],
            mode="markers",
            marker_color = batch['Person ID'],
            name="People",
        )
    )

    fig.update_layout(
             title = title,
         )

    fig.show()

# %%
create_plot_madrid(gdf,sub_gdf,'People moving around in Madrid')
# Out:
# <div>
#
#
#             <div id="0f95c00b-ae6b-4eb6-afa9-e6bcf434b128" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0f95c00b-ae6b-4eb6-afa9-e6bcf434b128")) {
#                     Plotly.newPlot(
#                         '0f95c00b-ae6b-4eb6-afa9-e6bcf434b128',
# ...

# %%
# Create plotly figure WITHOUT antennes for test 

# gdf is the database with antennes locations
# batch this the data that should be updated in the app

def create_plot_madrid_test(batch,title):
    import plotly.graph_objects as go
    import pandas as pd

    batch['text'] = batch['Person ID'].astype(str)

    fig = go.Figure()


    fig.add_trace(
        go.Scattergl(
            x=batch["x"],
            y=batch["y"],
            text = batch['text'],
            mode="markers",
            marker_color = batch['Person ID'],
            name="People",
        )
    )

    fig.update_layout(
             title = title,
         )

    fig.show()

# %%
create_plot_madrid_test(sub_gdf,'People moving around in Madrid')
# Out:
# <div>
#
#
#             <div id="23cfe4ff-fefb-4dd7-bf10-2a03424e6249" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("23cfe4ff-fefb-4dd7-bf10-2a03424e6249")) {
#                     Plotly.newPlot(
#                         '23cfe4ff-fefb-4dd7-bf10-2a03424e6249',
# ...
